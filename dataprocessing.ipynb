# %%
import numpy as np, pandas as pd

# %%
data_csv = pd.read_csv('ipdataset.csv', low_memory=False, header=None, nrows=20000)

# %%
data_csv.shape
# Out:
# (20000, 87)

# %%
data_csv.head()
# Out:
#                                      0             1            2   \
# 0                               Flow.ID     Source.IP  Source.Port
# 1   172.19.1.46-10.200.7.7-52422-3128-6   172.19.1.46        52422
# 2   172.19.1.46-10.200.7.7-52422-3128-6    10.200.7.7         3128
# 3  10.200.7.217-50.31.185.39-38848-80-6  50.31.185.39           80
# 4  10.200.7.217-50.31.185.39-38848-80-6  50.31.185.39           80
#
#                3                 4         5                   6   \
# 0  Destination.IP  Destination.Port  Protocol           Timestamp
# 1      10.200.7.7              3128         6  26/04/201711:11:17
# 2     172.19.1.46             52422         6  26/04/201711:11:17
# 3    10.200.7.217             38848         6  26/04/201711:11:17
# 4    10.200.7.217             38848         6  26/04/201711:11:17
#
#               7                  8                       9   ...          77  \
# 0  Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  ...  Active.Std
# ...

# %%
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 87 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20000 non-null  object
#  1   1       20000 non-null  object
#  2   2       20000 non-null  object
#  3   3       20000 non-null  object
#  4   4       20000 non-null  object
#  5   5       20000 non-null  object
#  6   6       20000 non-null  object
#  7   7       20000 non-null  object
#  8   8       20000 non-null  object
#  9   9       20000 non-null  object
#  10  10      20000 non-null  object
#  11  11      20000 non-null  object
#  12  12      20000 non-null  object
#  13  13      20000 non-null  object
#  14  14      20000 non-null  object
#  15  15      20000 non-null  object
#  16  16      20000 non-null  object
#  17  17      20000 non-null  object
#  18  18      20000 non-null  object
#  19  19      20000 non-null  object
#  20  20      20000 non-null  object
# ...

# %%
data_csv.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 82    0
# 83    0
# 84    0
# 85    0
# 86    0
# Length: 87, dtype: int64
